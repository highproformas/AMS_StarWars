# %%
import os
import json
import requests
import re 
import random
from time import sleep
import pandas as pd
import numpy as np
from datetime import datetime
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait, TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from lxml import html

# %% [markdown]
# # Network Data Load
#
# We are loading the network data and extract all character names.

# %%
DATA_PATH = './data'
FILES = dict()
for file_name in os.listdir(DATA_PATH):
    if file_name.startswith('gender_mapping'):
        continue
    full_file_path = os.path.join(DATA_PATH, file_name)
    FILES[os.path.splitext(file_name)[0]] = full_file_path

for k, v in FILES.items():
    print(k, '->', v)
# Out:
# starwars-episode-5-interactions -> ./data/starwars-episode-5-interactions.json
# starwars-episode-3-interactions -> ./data/starwars-episode-3-interactions.json
# starwars-episode-1-mentions -> ./data/starwars-episode-1-mentions.json
# starwars-episode-4-mentions -> ./data/starwars-episode-4-mentions.json
# starwars-full-interactions-allCharacters-merged -> ./data/starwars-full-interactions-allCharacters-merged.json
# starwars-episode-6-mentions -> ./data/starwars-episode-6-mentions.json
# starwars-episode-4-interactions -> ./data/starwars-episode-4-interactions.json
# starwars-episode-3-mentions -> ./data/starwars-episode-3-mentions.json
# starwars-episode-2-interactions -> ./data/starwars-episode-2-interactions.json
# starwars-episode-7-interactions -> ./data/starwars-episode-7-interactions.json
# starwars-episode-1-interactions-allCharacters -> ./data/starwars-episode-1-interactions-allCharacters.json
# starwars-episode-3-interactions-allCharacters -> ./data/starwars-episode-3-interactions-allCharacters.json
# starwars-episode-2-mentions -> ./data/starwars-episode-2-mentions.json
# starwars-episode-2-interactions-allCharacters -> ./data/starwars-episode-2-interactions-allCharacters.json
# starwars-episode-1-interactions -> ./data/starwars-episode-1-interactions.json
# starwars-episode-7-mentions -> ./data/starwars-episode-7-mentions.json
# starwars-full-interactions -> ./data/starwars-full-interactions.json
# starwars-episode-6-interactions -> ./data/starwars-episode-6-interactions.json
# starwars-full-interactions-allCharacters -> ./data/starwars-full-interactions-allCharacters.json
# starwars-episode-5-mentions -> ./data/starwars-episode-5-mentions.json
# starwars-episode-6-interactions-allCharacters -> ./data/starwars-episode-6-interactions-allCharacters.json
# starwars-episode-7-interactions-allCharacters -> ./data/starwars-episode-7-interactions-allCharacters.json
# starwars-episode-5-interactions-allCharacters -> ./data/starwars-episode-5-interactions-allCharacters.json
# starwars-episode-4-interactions-allCharacters -> ./data/starwars-episode-4-interactions-allCharacters.json
# starwars-full-mentions -> ./data/starwars-full-mentions.json

# %%
character_names = list()

def extract_names_from_network_definition(network):
    if 'nodes' not in network:
        return []
    characters = list()
    for node in network['nodes']:
        characters.append(node['name'])
    return characters

for k, v in FILES.items():
    with open(FILES[k]) as f:
        network = json.load(f)
    character_names.extend(extract_names_from_network_definition(network))

character_names = list(set(character_names))

# %%
len(character_names)
# Out:
# 113

# %%
character_names = sorted(character_names)

# %% [markdown]
# # Scrape the gender data of the characters
#
# The data can be found on the starwars "databank" and also sometimes the "wookieepedia".

# %%
databank = 'https://www.starwars.com/databank'
databank_tricky = 'https://www.starwars.com/search?q=####&f%5Bsearch_section%5D=Databank'
wookieepedia = 'https://starwars.fandom.com/wiki'
wookieepedia_tricky = 'https://starwars.fandom.com/wiki/Special:Search?query=####'

random.seed(1337)

# %%
def prepare_url(term, destination):
    if destination == 'databank':
        return f'{databank}/{term}'
    elif destination == 'databank_tricky':
        return databank_tricky.replace('####', term)
    elif destination == 'wookieepedia':
        return f'{wookieepedia}/{term}'
    elif destination == 'wookieepedia_tricky':
        return wookieepedia_tricky.replace('####', term)
    else:
        return term

# %% [markdown]
# The query function. It introduces a random timeout after each request to prevent the blocking of our IP.

# %%
def query(url):
    """Scraper method that adds a random delay to prevent DOSing the target.£"""
    response = requests.get(url)
    sleep(random.randint(1,3))
    return response

# %%
def convert_name(name, destination='databank'):
    """Converter method to make sure the name is properly formatted for the target website."""
    name = re.sub(r'\/', ' and ', name)
    if destination == 'databank':
        return name.lower().replace(' ', '-')
    elif destination == 'databank_tricky':
        return name.lower()
    elif destination == 'wookieepedia':
        return name.title().replace(' ', '_')
    elif destination == 'wookieepedia_tricky':
        return name.lower()
    else:
        return name

# %% [markdown]
# ## Databank query
#
# First we will query the databank. It should contain most of the information.
#
# Certain characters may not be found easily in the databank or are not available. Thus, we will override them.
#
# There are two way of searching:
# First, we attempt a direct method, i.e. we guess the right URL of the character detail page.
# Normally, if it is not a droid, then we will receive a "gender" in the stats section of the detail page.
# Gender information for droids will be extracted later on from the wookieepedia.
# Droids have either masculine or feminine programming, effectively making them either male or female.
# If the guessed URL returns a 404, we will use another method through the search functionality of the database.
# This way we try to extract the correct URL of the detail page from the search results.
# The tricky part here is, that the search results are sideloaded after the page load (AJAX), which prevents us from using the "request" module, we have to use "selenium" in that instance.
# Selenium waits until all results are visible and extracts then the URLs.
# We will only check the first 3 URLs, because if we don't find it in them, the search term is probably useless.
# Each URL will be trialed similar to the first direct method. Each page is checked whether it is the correct character page, and discarded if it is not.
# If no results can be found in either methods, then we will use the search term later on to search the wookieepedia.
#
# Some characters have been found especially tricky in either websites we are looking at. For those we consider "overrides" and directly assume their gender by a manual lookup.

# %%
# the following characters are known to contain a weird spelling on the database page. thus we will relax the verification steps.
weird_spellings_on_database = ['DARTH MAUL']
overrides = {
    'ANAKIN': 'Male', # database does not contain gender
    'YOUNG GIRL': 'Female', # implicit gender
    'RED LEADER': 'Male', # callsign of pilot
    'RED TEN': 'Male', # callsign of pilot
    'GOLD FIVE': 'Male', # callsign of pilot
    'GOLD LEADER': 'Male', # callsign of pilot
    'BRAVO THREE': 'Male', # callsign of pilot
    'BRAVO TWO': 'Male', # callsign of pilot
    'HAN': 'Male', # tricky to find
    'PK-4': 'Male', # tricky to find
    'FODE/BEED': 'Male', # tricky to find
    'SENATOR ASK AAK': 'Male' # tricky to find
}

# %%
def find_database_stat(container, lookup_stat):
    stat = None
    categories = container.find_all('div', {'class': 'category'})
    for category in categories:
        if category.find('div', {'class': 'heading'}).text.lower() == lookup_stat.lower():
            stat = category.find('li', {'class': 'data'}).text
            stat = re.sub(r'[^A-z\s]', '', stat.strip())
            break
    return stat

def extract_links_from_results_page(term, n=0):
    # we are using selenium here since the search results get side loaded with ajax after original page load
    options = Options()
    options.headless = True
    options.add_argument('--no-sandbox') 
    options.add_argument('--disable-dev-shm-usage') 
    try:
        if driver is not None:
            driver.quit()
    except:
        pass
    driver = webdriver.Chrome(options=options)
    driver.get(prepare_url(term, 'databank_tricky'))
    try:
        wait = WebDriverWait(driver, 5)
        wait.until(EC.visibility_of_element_located((By.CSS_SELECTOR, '.search_results')))
        urls = [element.get_attribute('href') for element in driver.find_elements(By.CSS_SELECTOR, '.result-title')]
    except TimeoutException:
        return []
    driver.quit()
    return urls if n == 0 else urls[:n]

def extract_gender_from_character_page(soup, character, check_correct_page=True):
    gender = None
    # verify we are on the right page
    if check_correct_page:
        title = soup.find_all('h3', {'class': 'title'})
        if not title:
            print('\tDid not find title element')
            return gender
        full_title = title[0].find_all('span', {'class': 'long-title'})
        needle = re.sub(r'[^A-z]', '', character).lower()
        haystack = re.sub(r'[^A-z]', '', full_title[0].text).lower()
        if not full_title or needle not in haystack or f'{needle}\'s' in haystack:
            # we are on the wrong page
            print('\tWrong page')
            return gender
    # extract
    stats_container = soup.find_all('div', {'class': 'stats-container'})
    if stats_container:
        container = stats_container[0]
        gender = find_database_stat(container, 'Gender')
        if gender is None:
            print('\tCould not extract gender from container')
            # most likely a droid
            droid = find_database_stat(container, 'Droid')
            if droid is not None:
                print('\tAssuming droid')
                gender = 'Droid'
            else:
                print('\tCould not determine whether droid or not')
        else:
            print(f'\tGender found: {gender}')
    else:
        print('\tNo Stats container found')
    return gender

def scrape_databank(characters):
    result = dict()
    for idx, character in enumerate(characters):
        print(f'Looking at character {str(idx+1)}/{len(characters)}: {character}')
        if character in overrides:
            print('\tUsing override')
            result[character] = overrides[character]
            print('Success!')
            continue
        # Build search url
        name = convert_name(name=character, destination='databank')
        # Query
        search_url = prepare_url(name, destination='databank')
        print(f'\tURL: {search_url}')
        page = query(search_url)
        # Verify Response
        not_found = page.url.replace('/','') == databank.replace('/','') or page.status_code == 404
        # Query Method
        if not not_found:
            print('\tGoing for the direct way')
            # Easy way if we find a direct hit
            soup = BeautifulSoup(page.content, 'html.parser')
            gender = extract_gender_from_character_page(soup, character, character not in weird_spellings_on_database)
            result[character] = gender
        else:
            print('\tGoing for the search result way')
            # Alternative way when not found initially
            search_name = convert_name(name=character, destination='databank_tricky')
            print(f'\tSearchterm: {search_name}')
            links = extract_links_from_results_page(name, 0)
            if not links:
                print('\tNo hits')
                result[character] = None
            else:
                for link in links[:min(len(links),3)]:
                    print(f'\tURL: {link}')
                    page = query(link) # no need to check if found, since it is provided by the engine
                    soup = BeautifulSoup(page.content, 'html.parser')
                    gender = extract_gender_from_character_page(soup, character)
                    if gender is not None:
                        break
                result[character] = gender
        print('Success!' if result[character] is not None else 'Nothing extracted.')
    return result

# %%
# runs for roughly 15min
gender_mapping_database = scrape_databank(character_names)
# Out:
# Looking at character 1/113: ADMIRAL ACKBAR
# 	URL: https://www.starwars.com/databank/admiral-ackbar
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 2/113: ADMIRAL STATURA
# 	URL: https://www.starwars.com/databank/admiral-statura
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 3/113: ANAKIN
# 	Using override
# Success!
# Looking at character 4/113: BAIL ORGANA
# 	URL: https://www.starwars.com/databank/bail-organa
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 5/113: BALA-TIK
# 	URL: https://www.starwars.com/databank/bala-tik
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 6/113: BB-8
# 	URL: https://www.starwars.com/databank/bb-8
# 	Going for the direct way
# 	Could not extract gender from container
# 	Assuming droid
# Success!
# Looking at character 7/113: BERU
# 	URL: https://www.starwars.com/databank/beru
# 	Going for the search result way
# 	Searchterm: beru
# 	URL: https://www.starwars.com/databank/beru-lars
# 	Gender found: Female
# Success!
# Looking at character 8/113: BIB FORTUNA
# 	URL: https://www.starwars.com/databank/bib-fortuna
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 9/113: BIGGS
# 	URL: https://www.starwars.com/databank/biggs
# 	Going for the search result way
# 	Searchterm: biggs
# 	URL: https://www.starwars.com/databank/biggs-darklighter
# 	Gender found: Male
# Success!
# Looking at character 10/113: BOBA FETT
# 	URL: https://www.starwars.com/databank/boba-fett
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 11/113: BOSS NASS
# 	URL: https://www.starwars.com/databank/boss-nass
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 12/113: BOUSHH
# 	URL: https://www.starwars.com/databank/boushh
# 	Going for the search result way
# 	Searchterm: boushh
# 	URL: https://www.starwars.com/databank/thermal-detonator
# 	Wrong page
# Nothing extracted.
# Looking at character 13/113: BRAVO THREE
# 	Using override
# Success!
# Looking at character 14/113: BRAVO TWO
# 	Using override
# Success!
# Looking at character 15/113: C-3PO
# 	URL: https://www.starwars.com/databank/c-3po
# 	Going for the direct way
# 	Could not extract gender from container
# 	Assuming droid
# Success!
# Looking at character 16/113: CAMIE
# 	URL: https://www.starwars.com/databank/camie
# 	Going for the search result way
# 	Searchterm: camie
# 	URL: https://www.starwars.com/databank/ben-quadinaros
# 	Wrong page
# Nothing extracted.
# Looking at character 17/113: CAPTAIN ANTILLES
# 	URL: https://www.starwars.com/databank/captain-antilles
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 18/113: CAPTAIN PANAKA
# 	URL: https://www.starwars.com/databank/captain-panaka
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 19/113: CAPTAIN PHASMA
# 	URL: https://www.starwars.com/databank/captain-phasma
# 	Going for the direct way
# 	Gender found: Female
# Success!
# Looking at character 20/113: CAPTAIN TYPHO
# 	URL: https://www.starwars.com/databank/captain-typho
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 21/113: CHEWBACCA
# 	URL: https://www.starwars.com/databank/chewbacca
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 22/113: CLIEGG
# 	URL: https://www.starwars.com/databank/cliegg
# 	Going for the search result way
# 	Searchterm: cliegg
# 	URL: https://www.starwars.com/databank/cliegg-lars
# 	Gender found: Male
# Success!
# Looking at character 23/113: CLONE COMMANDER CODY
# 	URL: https://www.starwars.com/databank/clone-commander-cody
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 24/113: CLONE COMMANDER GREE
# 	URL: https://www.starwars.com/databank/clone-commander-gree
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 25/113: COLONEL DATOO
# 	URL: https://www.starwars.com/databank/colonel-datoo
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 26/113: COUNT DOOKU
# 	URL: https://www.starwars.com/databank/count-dooku
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 27/113: DACK
# 	URL: https://www.starwars.com/databank/dack
# 	Going for the search result way
# 	Searchterm: dack
# 	URL: https://www.starwars.com/databank/malachor
# 	Wrong page
# 	URL: https://www.starwars.com/databank/sith-troopers
# 	Wrong page
# 	URL: https://www.starwars.com/databank/knights-of-ren
# 	Wrong page
# Nothing extracted.
# Looking at character 28/113: DARTH MAUL
# 	URL: https://www.starwars.com/databank/darth-maul
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 29/113: DARTH VADER
# 	URL: https://www.starwars.com/databank/darth-vader
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 30/113: DERLIN
# 	URL: https://www.starwars.com/databank/derlin
# 	Going for the search result way
# 	Searchterm: derlin
# 	URL: https://www.starwars.com/databank/major-bren-derlin
# 	Gender found: Male
# Success!
# Looking at character 31/113: DODONNA
# 	URL: https://www.starwars.com/databank/dodonna
# 	Going for the search result way
# 	Searchterm: dodonna
# 	URL: https://www.starwars.com/databank/jan-dodonna
# 	Gender found: Male
# Success!
# Looking at character 32/113: DOFINE
# 	URL: https://www.starwars.com/databank/dofine
# 	Going for the search result way
# 	Searchterm: dofine
# 	URL: https://www.starwars.com/databank/daultay-dofine
# 	Gender found: Male
# Success!
# Looking at character 33/113: ELLO ASTY
# 	URL: https://www.starwars.com/databank/ello-asty
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 34/113: EMPEROR
# 	URL: https://www.starwars.com/databank/emperor
# 	Going for the search result way
# 	Searchterm: emperor
# 	URL: https://www.starwars.com/databank/emperor-s-throne-room
# 	Could not extract gender from container
# 	Could not determine whether droid or not
# 	URL: https://www.starwars.com/databank/emperor-palpatine-darth-sidious
# 	Gender found: Male
# Success!
# Looking at character 35/113: FANG ZAR
# 	URL: https://www.starwars.com/databank/fang-zar
# 	Going for the search result way
# 	Searchterm: fang zar
# 	No hits
# Nothing extracted.
# Looking at character 36/113: FINN
# 	URL: https://www.starwars.com/databank/finn
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 37/113: FODE/BEED
# 	URL: https://www.starwars.com/databank/fode-and-beed
# 	Going for the direct way
# 	Wrong page
# Nothing extracted.
# Looking at character 38/113: GENERAL CEEL
# 	URL: https://www.starwars.com/databank/general-ceel
# 	Going for the search result way
# 	Searchterm: general ceel
# 	URL: https://www.starwars.com/databank/at-at-pilots
# 	Wrong page
# Nothing extracted.
# Looking at character 39/113: GENERAL GRIEVOUS
# 	URL: https://www.starwars.com/databank/general-grievous
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 40/113: GENERAL HUX
# 	URL: https://www.starwars.com/databank/general-hux
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 41/113: GIDDEAN DANU
# 	URL: https://www.starwars.com/databank/giddean-danu
# 	Going for the search result way
# 	Searchterm: giddean danu
# 	URL: https://www.starwars.com/databank/imperial-death-troopers
# 	Wrong page
# Nothing extracted.
# Looking at character 42/113: GOLD FIVE
# 	Using override
# Success!
# Looking at character 43/113: GOLD LEADER
# 	Using override
# Success!
# Looking at character 44/113: GREEDO
# 	URL: https://www.starwars.com/databank/greedo
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 45/113: HAN
# 	Using override
# Success!
# Looking at character 46/113: JABBA
# 	URL: https://www.starwars.com/databank/jabba
# 	Going for the search result way
# 	Searchterm: jabba
# 	URL: https://www.starwars.com/databank/jabba-the-hutt
# 	Gender found: Male
# Success!
# Looking at character 47/113: JANGO FETT
# 	URL: https://www.starwars.com/databank/jango-fett
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 48/113: JANSON
# 	URL: https://www.starwars.com/databank/janson
# 	Going for the search result way
# 	Searchterm: janson
# 	URL: https://www.starwars.com/databank/wes-janson
# 	Gender found: Male
# Success!
# Looking at character 49/113: JAR JAR
# 	URL: https://www.starwars.com/databank/jar-jar
# 	Going for the search result way
# 	Searchterm: jar jar
# 	URL: https://www.starwars.com/databank/jar-jar-binks
# 	Gender found: Male
# Success!
# Looking at character 50/113: JERJERROD
# 	URL: https://www.starwars.com/databank/jerjerrod
# 	Going for the search result way
# 	Searchterm: jerjerrod
# 	URL: https://www.starwars.com/databank/moff-jerjerrod
# 	Gender found: Male
# Success!
# Looking at character 51/113: JESS
# 	URL: https://www.starwars.com/databank/jess
# 	Going for the search result way
# 	Searchterm: jess
# 	URL: https://www.starwars.com/databank/jess-pava
# 	Gender found: Female
# Success!
# Looking at character 52/113: JIRA
# 	URL: https://www.starwars.com/databank/jira
# 	Going for the direct way
# 	Gender found: Female
# Success!
# Looking at character 53/113: JOBAL
# 	URL: https://www.starwars.com/databank/jobal
# 	Going for the search result way
# 	Searchterm: jobal
# 	URL: https://www.starwars.com/databank/mayfeld
# 	Wrong page
# 	URL: https://www.starwars.com/databank/qin
# 	Wrong page
# 	URL: https://www.starwars.com/databank/phase-connector
# 	Wrong page
# Nothing extracted.
# Looking at character 54/113: KI-ADI-MUNDI
# 	URL: https://www.starwars.com/databank/ki-adi-mundi
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 55/113: KITSTER
# 	URL: https://www.starwars.com/databank/kitster
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 56/113: KYLO REN
# 	URL: https://www.starwars.com/databank/kylo-ren
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 57/113: LAMA SU
# 	URL: https://www.starwars.com/databank/lama-su
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 58/113: LANDO
# 	URL: https://www.starwars.com/databank/lando
# 	Going for the search result way
# 	Searchterm: lando
# 	URL: https://www.starwars.com/databank/lando-s-prod-pistol
# 	Could not extract gender from container
# 	Could not determine whether droid or not
# 	URL: https://www.starwars.com/databank/lando-calrissian
# 	Gender found: Male
# Success!
# Looking at character 59/113: LEIA
# 	URL: https://www.starwars.com/databank/leia
# 	Going for the search result way
# 	Searchterm: leia
# 	URL: https://www.starwars.com/databank/leia-organa
# 	Gender found: Female
# Success!
# Looking at character 60/113: LIEUTENANT MITAKA
# 	URL: https://www.starwars.com/databank/lieutenant-mitaka
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 61/113: LOR SAN TEKKA
# 	URL: https://www.starwars.com/databank/lor-san-tekka
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 62/113: LUKE
# 	URL: https://www.starwars.com/databank/luke
# 	Going for the search result way
# 	Searchterm: luke
# 	URL: https://www.starwars.com/databank/luke-skywalker
# 	Gender found: Male
# Success!
# Looking at character 63/113: MACE WINDU
# 	URL: https://www.starwars.com/databank/mace-windu
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 64/113: MAZ
# 	URL: https://www.starwars.com/databank/maz
# 	Going for the search result way
# 	Searchterm: maz
# 	URL: https://www.starwars.com/databank/mazs-castle
# 	Could not extract gender from container
# 	Could not determine whether droid or not
# 	URL: https://www.starwars.com/databank/maz-kanata
# 	Gender found: Female
# Success!
# Looking at character 65/113: MON MOTHMA
# 	URL: https://www.starwars.com/databank/mon-mothma
# 	Going for the direct way
# 	Gender found: Female
# Success!
# Looking at character 66/113: MOTTI
# 	URL: https://www.starwars.com/databank/motti
# 	Going for the search result way
# 	Searchterm: motti
# 	URL: https://www.starwars.com/databank/admiral-motti
# 	Gender found: Male
# Success!
# Looking at character 67/113: NEEDA
# 	URL: https://www.starwars.com/databank/needa
# 	Going for the search result way
# 	Searchterm: needa
# 	URL: https://www.starwars.com/databank/captain-needa
# 	Gender found: Male
# Success!
# Looking at character 68/113: NIV LEK
# 	URL: https://www.starwars.com/databank/niv-lek
# 	Going for the search result way
# 	Searchterm: niv lek
# 	No hits
# Nothing extracted.
# Looking at character 69/113: NUTE GUNRAY
# 	URL: https://www.starwars.com/databank/nute-gunray
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 70/113: OBI-WAN
# 	URL: https://www.starwars.com/databank/obi-wan
# 	Going for the search result way
# 	Searchterm: obi-wan
# 	URL: https://www.starwars.com/databank/obi-wan-kenobi
# 	Gender found: Male
# Success!
# Looking at character 71/113: ODD BALL
# 	URL: https://www.starwars.com/databank/odd-ball
# 	Going for the search result way
# 	Searchterm: odd ball
# 	URL: https://www.starwars.com/databank/clone-pilot-odd-ball
# 	Gender found: Male
# Success!
# Looking at character 72/113: ORN FREE TAA
# 	URL: https://www.starwars.com/databank/orn-free-taa
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 73/113: OWEN
# 	URL: https://www.starwars.com/databank/owen
# 	Going for the search result way
# 	Searchterm: owen
# 	URL: https://www.starwars.com/databank/owen-lars
# 	Gender found: Male
# Success!
# Looking at character 74/113: OZZEL
# 	URL: https://www.starwars.com/databank/ozzel
# 	Going for the search result way
# 	Searchterm: ozzel
# 	URL: https://www.starwars.com/databank/admiral-ozzel
# 	Gender found: Male
# Success!
# Looking at character 75/113: PADME
# 	URL: https://www.starwars.com/databank/padme
# 	Going for the search result way
# 	Searchterm: padme
# 	URL: https://www.starwars.com/databank/padmes-apartment
# 	Wrong page
# 	URL: https://www.starwars.com/databank/padme-amidala
# 	Wrong page
# 	URL: https://www.starwars.com/databank/dorme
# 	Wrong page
# Nothing extracted.
# Looking at character 76/113: PIETT
# 	URL: https://www.starwars.com/databank/piett
# 	Going for the search result way
# 	Searchterm: piett
# 	URL: https://www.starwars.com/databank/admiral-piett
# 	Gender found: Male
# Success!
# Looking at character 77/113: PK-4
# 	Using override
# Success!
# Looking at character 78/113: PLO KOON
# 	URL: https://www.starwars.com/databank/plo-koon
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 79/113: POE
# 	URL: https://www.starwars.com/databank/poe
# 	Going for the search result way
# 	Searchterm: poe
# 	URL: https://www.starwars.com/databank/poe-dameron
# 	Gender found: Male
# Success!
# Looking at character 80/113: POGGLE
# 	URL: https://www.starwars.com/databank/poggle
# 	Going for the search result way
# 	Searchterm: poggle
# 	URL: https://www.starwars.com/databank/poggle-the-lesser
# 	Gender found: Male
# Success!
# Looking at character 81/113: QUI-GON
# 	URL: https://www.starwars.com/databank/qui-gon
# 	Going for the search result way
# 	Searchterm: qui-gon
# 	URL: https://www.starwars.com/databank/qui-gon-jinn
# 	Gender found: Male
# Success!
# Looking at character 82/113: R2-D2
# 	URL: https://www.starwars.com/databank/r2-d2
# 	Going for the direct way
# 	Could not extract gender from container
# 	Assuming droid
# Success!
# Looking at character 83/113: RABE
# 	URL: https://www.starwars.com/databank/rabe
# 	Going for the search result way
# 	Searchterm: rabe
# 	URL: https://www.starwars.com/databank/flix
# 	Wrong page
# 	URL: https://www.starwars.com/databank/sinrich-optical-dephaser
# 	Wrong page
# 	URL: https://www.starwars.com/databank/phase-connector
# 	Wrong page
# Nothing extracted.
# Looking at character 84/113: RED LEADER
# 	Using override
# Success!
# Looking at character 85/113: RED TEN
# 	Using override
# Success!
# Looking at character 86/113: REY
# 	URL: https://www.starwars.com/databank/rey
# 	Going for the direct way
# 	Gender found: Female
# Success!
# Looking at character 87/113: RIC OLIE
# 	URL: https://www.starwars.com/databank/ric-olie
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 88/113: RIEEKAN
# 	URL: https://www.starwars.com/databank/rieekan
# 	Going for the search result way
# 	Searchterm: rieekan
# 	URL: https://www.starwars.com/databank/general-rieekan
# 	Gender found: Male
# Success!
# Looking at character 89/113: RUNE
# 	URL: https://www.starwars.com/databank/rune
# 	Going for the search result way
# 	Searchterm: rune
# 	URL: https://www.starwars.com/databank/rune-haako
# 	Gender found: Male
# Success!
# Looking at character 90/113: RUWEE
# 	URL: https://www.starwars.com/databank/ruwee
# 	Going for the search result way
# 	Searchterm: ruwee
# 	URL: https://www.starwars.com/databank/clan-kryze
# 	Wrong page
# 	URL: https://www.starwars.com/databank/razoo-qin-fee
# 	Wrong page
# 	URL: https://www.starwars.com/databank/lark-and-jonk-a-k-a-the-twins
# 	Wrong page
# Nothing extracted.
# Looking at character 91/113: SEBULBA
# 	URL: https://www.starwars.com/databank/sebulba
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 92/113: SENATOR ASK AAK
# 	URL: https://www.starwars.com/databank/senator-ask-aak
# 	Going for the search result way
# 	Searchterm: senator ask aak
# 	URL: https://www.starwars.com/databank/ask-aak
# 	Wrong page
# 	URL: https://www.starwars.com/databank/gran
# 	Wrong page
# 	URL: https://www.starwars.com/databank/supreme-chancellor-valorum
# 	Wrong page
# Nothing extracted.
# Looking at character 93/113: SHMI
# 	URL: https://www.starwars.com/databank/shmi
# 	Going for the search result way
# 	Searchterm: shmi
# 	URL: https://www.starwars.com/databank/shmi-skywalker-lars
# 	Gender found: Female
# Success!
# Looking at character 94/113: SIO BIBBLE
# 	URL: https://www.starwars.com/databank/sio-bibble
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 95/113: SNAP
# 	URL: https://www.starwars.com/databank/snap
# 	Going for the search result way
# 	Searchterm: snap
# 	URL: https://www.starwars.com/databank/snap-wexley
# 	Gender found: Male
# Success!
# Looking at character 96/113: SNOKE
# 	URL: https://www.starwars.com/databank/snoke
# 	Going for the search result way
# 	Searchterm: snoke
# 	URL: https://www.starwars.com/databank/snokes-throne-room
# 	Could not extract gender from container
# 	Could not determine whether droid or not
# 	URL: https://www.starwars.com/databank/supreme-leader-snoke
# 	Gender found: Male
# Success!
# Looking at character 97/113: SOLA
# 	URL: https://www.starwars.com/databank/sola
# 	Going for the search result way
# 	Searchterm: sola
# 	URL: https://www.starwars.com/databank/han-solo
# 	Wrong page
# 	URL: https://www.starwars.com/databank/han-solos-landspeeder
# 	Wrong page
# 	URL: https://www.starwars.com/databank/han-solo-s-dice
# 	Wrong page
# Nothing extracted.
# Looking at character 98/113: SUN RIT
# 	URL: https://www.starwars.com/databank/sun-rit
# 	Going for the search result way
# 	Searchterm: sun rit
# 	No hits
# Nothing extracted.
# Looking at character 99/113: TARKIN
# 	URL: https://www.starwars.com/databank/tarkin
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 100/113: TARPALS
# 	URL: https://www.starwars.com/databank/tarpals
# 	Going for the search result way
# 	Searchterm: tarpals
# 	URL: https://www.starwars.com/databank/general-tarpals
# 	Gender found: Male
# Success!
# Looking at character 101/113: TAUN WE
# 	URL: https://www.starwars.com/databank/taun-we
# 	Going for the direct way
# 	Gender found: Female
# Success!
# Looking at character 102/113: TC-14
# 	URL: https://www.starwars.com/databank/tc-14
# 	Going for the direct way
# 	Could not extract gender from container
# 	Assuming droid
# Success!
# Looking at character 103/113: TEY HOW
# 	URL: https://www.starwars.com/databank/tey-how
# 	Going for the search result way
# 	Searchterm: tey how
# 	No hits
# Nothing extracted.
# Looking at character 104/113: TION MEDON
# 	URL: https://www.starwars.com/databank/tion-medon
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 105/113: UNKAR PLUTT
# 	URL: https://www.starwars.com/databank/unkar-plutt
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 106/113: VALORUM
# 	URL: https://www.starwars.com/databank/valorum
# 	Going for the search result way
# 	Searchterm: valorum
# 	URL: https://www.starwars.com/databank/supreme-chancellor-valorum
# 	Gender found: Male
# Success!
# Looking at character 107/113: WALD
# 	URL: https://www.starwars.com/databank/wald
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 108/113: WATTO
# 	URL: https://www.starwars.com/databank/watto
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 109/113: WEDGE
# 	URL: https://www.starwars.com/databank/wedge
# 	Going for the search result way
# 	Searchterm: wedge
# 	URL: https://www.starwars.com/databank/wedge-antilles
# 	Gender found: Male
# Success!
# Looking at character 110/113: YODA
# 	URL: https://www.starwars.com/databank/yoda
# 	Going for the direct way
# 	Gender found: Male
# Success!
# Looking at character 111/113: YOLO ZIFF
# 	URL: https://www.starwars.com/databank/yolo-ziff
# 	Going for the search result way
# 	Searchterm: yolo ziff
# 	No hits
# Nothing extracted.
# Looking at character 112/113: YOUNG GIRL
# 	Using override
# Success!
# Looking at character 113/113: ZEV
# 	URL: https://www.starwars.com/databank/zev
# 	Going for the search result way
# 	Searchterm: zev
# 	URL: https://www.starwars.com/databank/zev-senesca
# 	Gender found: Male
# Success!

# %% [markdown]
# ### Get an Overview
#
# Let's get an overview what we have found so far.

# %%
counter = 0
for k,v in gender_mapping_database.items():
    if v is None:
        continue
    if 'Droid' in v:
        counter += 1
        print(f'{counter}:\t{k} - {v}')
print('-'*20)
counter = 0
for k,v in gender_mapping_database.items():
    if v is None:
        counter += 1
        print(f'{counter}:\t{k} - {v}')
# Out:
# 1:	BB-8 - Droid
# 2:	C-3PO - Droid
# 3:	R2-D2 - Droid
# 4:	TC-14 - Droid
# --------------------
# 1:	BOUSHH - None
# 2:	CAMIE - None
# 3:	DACK - None
# 4:	FANG ZAR - None
# 5:	FODE/BEED - None
# 6:	GENERAL CEEL - None
# 7:	GIDDEAN DANU - None
# 8:	JOBAL - None
# 9:	NIV LEK - None
# 10:	PADME - None
# 11:	RABE - None
# 12:	RUWEE - None
# 13:	SENATOR ASK AAK - None
# 14:	SOLA - None
# 15:	SUN RIT - None
# 16:	TEY HOW - None
# 17:	YOLO ZIFF - None

# %% [markdown]
# ### Query the Droids
#
# The droid programming information can be found on wookieepedia. From there we derive if it is a "Male" droid or a "Female" droid from the type of programming (voice).

# %%
def extract_gender_from_droid_page(soup, droid, check_correct_page=True):
    gender = None
    # verify we are on the right page
    if check_correct_page:
        title = soup.find_all('h2', attrs={'data-source' : 'name'})
        if not title:
            print('\tDid not find title element')
            return gender
        full_title = title[0].text
        needle = re.sub(r'[^A-z]', '', droid).lower()
        haystack = re.sub(r'[^A-z]', '', full_title).lower()
        if not full_title or needle not in haystack:
            # we are on the wrong page
            print('\tWrong page')
            return gender
    # extract
    gender_element = soup.find_all('a', attrs={'title' : 'Sexes'})
    if gender_element:
        element = gender_element[0].text
        if 'Masculin' in element or 'Male' in element:
            gender = 'Male'
        elif 'Feminin' in element or 'Female' in element:
            gender = 'Female'
    else:
        print('\tNo Gender Element found')
    return gender

def scrape_wookieepedia_direct_for_droids(characters):
    result = dict()
    for idx, character in enumerate(characters):
        print(f'Looking at droid {str(idx+1)}/{len(characters)}: {character}')
        # Query
        search_url = prepare_url(character, destination='wookieepedia')
        print(f'\tURL: {search_url}')
        page = query(search_url)
        # Easy way if we find a direct hit
        soup = BeautifulSoup(page.content, 'html.parser')
        # extract
        gender = extract_gender_from_droid_page(soup, character)
        if gender is None:
            gender = 'Droid'
        result[character] = gender
    return result 


droids = dict(filter(lambda character: character[1] == 'Droid' , gender_mapping_database.items()))
droid_genders = scrape_wookieepedia_direct_for_droids(droids)
# update master mapping
gender_mapping_database = {**gender_mapping_database, **droid_genders}
# checking if we still have droids unresolved
assert dict(filter(lambda character: character[1] == 'Droid' , gender_mapping_database.items())) == {}, 'There are still droids you are looking for.'
# Out:
# Looking at droid 1/4: BB-8
# 	URL: https://starwars.fandom.com/wiki/BB-8
# Looking at droid 2/4: C-3PO
# 	URL: https://starwars.fandom.com/wiki/C-3PO
# Looking at droid 3/4: R2-D2
# 	URL: https://starwars.fandom.com/wiki/R2-D2
# Looking at droid 4/4: TC-14
# 	URL: https://starwars.fandom.com/wiki/TC-14

# %% [markdown]
# ## Query the remaining characters

# %%
def extract_links_from_wookieepedia_results_page(term, n=0):
    # we are using selenium here for no apparent reason
    options = Options()
    options.headless = True
    options.add_argument('--no-sandbox') 
    options.add_argument('--disable-dev-shm-usage') 
    try:
        if driver is not None:
            driver.quit()
    except:
        pass
    driver = webdriver.Chrome(options=options)
    driver.get(prepare_url(term, 'wookieepedia_tricky'))
    try:
        wait = WebDriverWait(driver, 5)
        wait.until(EC.visibility_of_element_located((By.CSS_SELECTOR, '.unified-search__results')))
        urls = [element.get_attribute('href') for element in driver.find_elements(By.CSS_SELECTOR, '.unified-search__result__title')]
    except TimeoutException:
        return []
    driver.quit()
    return urls if n == 0 else urls[:n]

def extract_gender_from_wookieepedia_character_page(soup, character, check_correct_page=True):
    gender = None
    # verify we are on the right page
    if check_correct_page:
        character_info = soup.find_all('aside', {'class': 'pi-theme-character'})
        if not character_info:
            print('\tDid not find character info')
            return gender
        title = soup.find_all('h2', attrs={'data-source' : 'name'})
        if not title:
            print('\tDid not find title element')
            return gender
        full_title = title[0].text
        needle = re.sub(r'[^A-z]', '', character).lower()
        haystack = re.sub(r'[^A-z]', '', full_title).lower()
        if not full_title or needle not in haystack:
            # we are on the wrong page
            print('\tWrong page')
            return gender
    # extract
    gender_element = soup.find_all('a', attrs={'title' : ['Sexes', 'Sexes/Legends']})
    if gender_element:
        element = gender_element[0].text
        if 'Male' in element:
            gender = 'Male'
        elif 'Female' in element:
            gender = 'Female'
    else:
        print('\tNo Gender Element found')
    return gender

def scrape_wookieepedia_search_for_remaining(characters):
    result = dict()
    for idx, character in enumerate(characters):
        print(f'Looking at character {str(idx+1)}/{len(characters)}: {character}')
        if character in overrides:
            print('\tUsing override')
            result[character] = overrides[character]
            print('Success!')
            continue
        # Build search url
        name = convert_name(name=character, destination='wookieepedia')
        # Query
        search_url = prepare_url(name, destination='wookieepedia')
        print(f'\tURL: {search_url}')
        page = query(search_url)
        # Verify Response
        not_found = page.url.replace('/','') == databank.replace('/','') or page.status_code == 404
        # Query Method
        if not not_found:
            print('\tGoing for the direct way')
            # Easy way if we find a direct hit
            soup = BeautifulSoup(page.content, 'html.parser')
            gender = extract_gender_from_wookieepedia_character_page(soup, character, False)
            result[character] = gender
        else:
            print('\tGoing for the search result way')
            # Alternative way when not found initially
            search_name = convert_name(name=character, destination='wookieepedia_tricky')
            print(f'\tSearchterm: {search_name}')
            links = extract_links_from_wookieepedia_results_page(name, 0)
            if not links:
                print('\tNo hits')
                result[character] = None
            else:
                for link in links[:min(len(links),3)]:
                    print(f'\tURL: {link}')
                    page = query(link) # no need to check if found, since it is provided by the engine
                    soup = BeautifulSoup(page.content, 'html.parser')
                    gender = extract_gender_from_wookieepedia_character_page(soup, character)
                    if gender is not None:
                        break
                result[character] = gender
        print('Success!' if result[character] is not None else 'Nothing extracted.')
    return result

# %%
remaining = dict(filter(lambda character: character[1] is None , gender_mapping_database.items()))
remaining_genders = scrape_wookieepedia_search_for_remaining(remaining)
# Out:
# Looking at character 1/7: DACK
# 	URL: https://starwars.fandom.com/wiki/Dack
# 	Going for the direct way
# Success!
# Looking at character 2/7: GENERAL CEEL
# 	URL: https://starwars.fandom.com/wiki/General_Ceel
# 	Going for the direct way
# Success!
# Looking at character 3/7: JOBAL
# 	URL: https://starwars.fandom.com/wiki/Jobal
# 	Going for the direct way
# Success!
# Looking at character 4/7: RABE
# 	URL: https://starwars.fandom.com/wiki/Rabe
# 	Going for the direct way
# Success!
# Looking at character 5/7: SENATOR ASK AAK
# 	Using override
# Success!
# Looking at character 6/7: SOLA
# 	URL: https://starwars.fandom.com/wiki/Sola
# 	Going for the direct way
# Success!
# Looking at character 7/7: SUN RIT
# 	URL: https://starwars.fandom.com/wiki/Sun_Rit
# 	Going for the direct way
# Success!

# %% [markdown]
# ### Update
#
# Let's update what we have found.

# %%
gender_mapping_database = {**gender_mapping_database, **remaining_genders}

# %% [markdown]
# There might be still some genders left. Let's have a look and add them manually.

# %%
still_unresolved = dict(filter(lambda character: character[1] is None , gender_mapping_database.items()))
print(still_unresolved)
assert still_unresolved == {}, 'Still some left. They might be added in the overrides.'
# Out:
# {}

# %%
def store(mapping):
    data = dict()
    nodes = list()
    for k, v in mapping.items():
        nodes.append({'name': k, 'gender': v})
    data['nodes'] = nodes
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = os.path.join(DATA_PATH, f'gender_mapping_{timestamp}.json')
    with open(filename, 'w') as fp:
        json.dump(data, fp)

store(gender_mapping_database)

# %%
os.listdir(DATA_PATH)
# Out:
# ['starwars-episode-5-interactions.json',
#  'starwars-episode-3-interactions.json',
#  'starwars-episode-1-mentions.json',
#  'starwars-episode-4-mentions.json',
#  'starwars-full-interactions-allCharacters-merged.json',
#  'starwars-episode-6-mentions.json',
#  'starwars-episode-4-interactions.json',
#  'starwars-episode-3-mentions.json',
#  'starwars-episode-2-interactions.json',
#  'starwars-episode-7-interactions.json',
#  'starwars-episode-1-interactions-allCharacters.json',
#  'starwars-episode-3-interactions-allCharacters.json',
#  'starwars-episode-2-mentions.json',
#  'gender_mapping_20201205_112121.json',
#  'starwars-episode-2-interactions-allCharacters.json',
#  'starwars-episode-1-interactions.json',
#  'starwars-episode-7-mentions.json',
#  'starwars-full-interactions.json',
#  'starwars-episode-6-interactions.json',
#  'starwars-full-interactions-allCharacters.json',
#  'starwars-episode-5-mentions.json',
#  'starwars-episode-6-interactions-allCharacters.json',
#  'starwars-episode-7-interactions-allCharacters.json',
#  'starwars-episode-5-interactions-allCharacters.json',
#  'starwars-episode-4-interactions-allCharacters.json',
#  'starwars-full-mentions.json']
